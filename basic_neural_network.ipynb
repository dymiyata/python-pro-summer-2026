# %% [markdown]
# <a href="https://colab.research.google.com/github/dymiyata/python-pro-summer-2026/blob/main/basic_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers

# %%
# make fake data

m = 100

x1 = np.random.randint(-5, 5, m)
x2 = np.random.randint(-5, 5, m)
x3 = np.random.randint(-5, 5, m)

X = np.column_stack([x1, x2, x3])

# %%
score = x1**2 + 3 * x2 - x3
y = (score > 10).astype(np.float32)

# %%
# Defining the network
model = keras.Sequential([
    layers.Input(shape=(3,)),
    layers.Dense(4, activation="relu"),
    layers.Dense(4, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
# Specifying how it will train
model.compile(
    optimizer="adam",
    loss="crossentropy",
    metrics=["accuracy"]
)

# %%
model.fit(X,y, epochs=100)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5000 - loss: 0.7321
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4600 - loss: 0.7214
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4700 - loss: 0.7120
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4700 - loss: 0.7048
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4700 - loss: 0.6978
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4700 - loss: 0.6907
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4700 - loss: 0.6844
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4700 - loss: 0.6793
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4800 - loss: 0.6741
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4800 - loss: 0.6694
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4800 - loss: 0.6655
# Epoch 12/100
# ...
